# %%
import pandas as pd
import numpy as np
location = "datasets/kickstartercombo (1).csv"
df = pd.read_csv(location)

# %%
df.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000004038                                     Where is Hank?
# 2           2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4           4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency             launched             deadline  backers  usd pledged  \
# ...

# %%
df.count()
# Out:
# Unnamed: 0          702411
# ID                  702411
# name                702403
# main_category       702411
# category            702411
# country             702411
# state               702411
# goal                702411
# pledged             702411
# currency            702411
# launched            702411
# deadline            702411
# backers             702411
# usd pledged         694817
# usd_goal_real       378661
# usd_pledged_real    378661
# dtype: int64

# %%
df['main_category'].value_counts()
# Out:
# Film & Video      121331
# Music              98710
# Publishing         74220
# Games              63272
# Technology         58730
# Design             53979
# Art                52177
# Food               45844
# Fashion            41232
# Theater            20888
# Photography        20468
# Comics             19575
# Crafts             16001
# Journalism          8838
# Dance               7145
# Graphic Novels         1
# Name: main_category, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# name                     8
# main_category            0
# category                 0
# country                  0
# state                    0
# goal                     0
# pledged                  0
# currency                 0
# launched                 0
# deadline                 0
# backers                  0
# usd pledged           7594
# usd_goal_real       323750
# usd_pledged_real    323750
# dtype: int64

# %%
df.sort_values('goal',ascending=True)
# Out:
#         Unnamed: 0          ID  \
# 628239      628239   620302213
# 260569      260569   620302213
# 641521      641521   688564643
# 271909      271909   688564643
# 316694      316694     9572984
# 694151      694151     9572984
# 549921      549921   219760504
# 193585      193585   219760504
# 671759      671759   842973116
# 197579      197579    24344396
# 95627        95627   156802730
# 139775      139775  1830689058
# 573409      573409   339792913
# 513391      513391  1965183518
# 204755      204755   286384979
# 59076        59076  1351052522
# 539077      539077   209708644
# 69407        69407  1412689603
# 16996        16996  1100301633
# 340642      340642  1085633926
# 281514      281514   746569507
# 329602      329602  1030025420
# 636022      636022    66066815
# 599931      599931   475130467
# 118580      118580  1703892588
# 263497      263497   638442476
# 530127      530127  2051479991
# 205605      205605   291858502
# 599957      599957   475321154
# ...

# %%
df.sort_values('currency')
# Out:
#         Unnamed: 0          ID  \
# 154062      154062  1915504176
# 499994      499994  1896509261
# 341829      341829  1091679814
# 25898        25898  1153355240
# 76511        76511  1454432305
# 681652      681652   893200716
# 402560      402560  1401008008
# 601788      601788   484678142
# 640901      640901   685520092
# 297815      297815   844549413
# 500003      500003  1896572748
# 681680      681680   893350596
# 373730      373730  1254730921
# 297825      297825   844615918
# 681689      681689   893407560
# 601773      601773   484586119
# 451680      451680  1649320325
# 164583      164583  1978658222
# 146654      146654  1871247557
# 125175      125175   174338697
# 439699      439699  1588706687
# 297814      297814   844542354
# 164562      164562  1978524136
# 220523      220523   380157514
# 681587      681587   892923581
# 326166      326166  1012513938
# 584347      584347   395524066
# 220529      220529    38019017
# 373667      373667  1254333765
# ...

# %%
df['currency'].value_counts()
# Out:
# USD    556182
# GBP     62165
# EUR     28972
# CAD     27176
# AUD     14312
# SEK      3090
# NZD      2640
# DKK      1970
# MXN      1966
# NOK      1262
# CHF      1246
# HKD       715
# SGD       675
# JPY        40
# Name: currency, dtype: int64

# %%
df.dropna()
# Out:
#         Unnamed: 0          ID  \
# 323750      323750  1000002330
# 323751      323751  1000003930
# 323752      323752  1000004038
# 323753      323753  1000007540
# 323754      323754  1000011046
# 323755      323755  1000014025
# 323756      323756  1000023410
# 323757      323757  1000030581
# 323758      323758  1000034518
# 323759      323759   100004195
# 323760      323760   100004721
# 323761      323761   100005484
# 323762      323762  1000055792
# 323763      323763  1000056157
# 323764      323764  1000057089
# 323765      323765  1000064368
# 323766      323766  1000064918
# 323767      323767  1000068480
# 323768      323768  1000070642
# 323769      323769  1000071625
# 323770      323770  1000072011
# 323771      323771  1000081649
# 323772      323772  1000082254
# 323773      323773  1000087442
# 323774      323774  1000091520
# 323775      323775  1000102741
# 323776      323776  1000103948
# 323777      323777  1000104688
# 323778      323778  1000104953
# ...

# %%
df.dropna(axis=1)
# Out:
#         Unnamed: 0          ID main_category          category country  \
# 0                0  1000002330    Publishing            Poetry      GB
# 1                1  1000004038  Film & Video    Narrative Film      US
# 2                2  1000007540         Music             Music      US
# 3                3  1000011046  Film & Video      Film & Video      US
# 4                4  1000014025          Food       Restaurants      US
# 5                5  1000023410          Food              Food      US
# 6                6  1000030581          Food            Drinks      US
# 7                7  1000034518        Design    Product Design      US
# 8                8   100004195  Film & Video       Documentary      US
# 9                9   100004721    Publishing        Nonfiction      CA
# 10              10   100005484         Music        Indie Rock      US
# 11              11  1000055792        Crafts            Crafts      US
# ...

# %%
df.sort_values(by='usd_goal_real'ascending=False)
df.sort_values(by='backers'ascending=False)
df.sort_values(by='state', ascending=False)
# Out:
#   File "<ipython-input-91-70af27ebe823>", line 1
#     df.sort_values(by='usd_goal_real'ascending=False)
#                                              ^
# SyntaxError: invalid syntax

# %%
df.sort_values(['main_category'])
# Out:
#         Unnamed: 0          ID  \
# 702410      702410   999988282
# 84346        84346  1500430001
# 633108      633108   645789799
# 282329      282329   751531671
# 282340      282340    75156034
# 84330        84330  1500365185
# 84326        84326  1500356897
# 471671      471671  1751751341
# 282359      282359   751658237
# 84315        84315  1500319810
# 84311        84311   150030257
# 471656      471656  1751662151
# 471648      471648  1751639087
# 471641      471641  1751614050
# 471633      471633  1751581426
# 282399      282399   751854304
# 633107      633107     6457893
# 282325      282325   751523887
# 84350        84350  1500457543
# 282309      282309   751420667
# 282251      282251   751076272
# 84391        84391  1500704573
# 471733      471733  1752097539
# 282275      282275   751273320
# 471723      471723   175204899
# 633082      633082   645657720
# 633084      633084   645667188
# 471629      471629  1751538487
# 282287      282287   751319901
# ...

# %%
df.drop_duplicates('failed',)

# %% [markdown]
# df.sort_values('Main_category

# %%
df['main_category=art'] = pd.Categorical(df['Music'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Music'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-d0dd63ffb3e8> in <module>
# ...
